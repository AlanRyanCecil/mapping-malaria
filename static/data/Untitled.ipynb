# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Malaria_data_file.csv')

# %%
df.groupby('Country').mean().sort_values('Malaria cases/100,000 pop.', ascending=False).head(10)
# Out:
#                  Year   GDP/capita    Population  Malaria cases/100,000 pop.  \
# Country
# Guinea         2012.5  1234.584789  1.061720e+07                38642.320635
# Uganda         2009.5  1516.892363  3.296645e+07                37841.343943
# Mozambique     2009.5   907.828593  2.313972e+07                31488.750265
# Cote d'Ivoire  2010.5  2694.132979  1.997994e+07                31275.495317
# Sierra Leone   2012.5  1528.909436  6.190806e+06                30751.765310
# Malawi         2010.5  1021.757494  1.516982e+07                30311.493992
# Burkina Faso   2009.5  1402.407532  1.626414e+07                29015.172741
# Liberia        2012.5   795.247408  4.296712e+06                28218.723210
# Ghana          2010.5  3276.074130  2.468725e+07                27404.355735
# Chad           2009.5  1841.642473  1.109649e+07                26233.508219
#
#                Under-5s (per 100,000)  All ages (per 100,000)  \
# Country
# ...

# %%
df.loc[df['Country'] == 'Chad']
# Out:
#      Year Country Country Code   GDP/capita  Population  \
# 95   2006    Chad          TCD  1743.617851  10084087.0
# 209  2007    Chad          TCD  1741.487056  10371839.0
# 327  2008    Chad          TCD  1736.919173  10653762.0
# 444  2009    Chad          TCD  1752.119931  10937089.0
# 517  2010    Chad          TCD  1925.195118  11227208.0
# 586  2011    Chad          TCD  1863.845605  11525496.0
# 658  2012    Chad          TCD  1962.877730  11830573.0
# 734  2013    Chad          TCD  2007.077319  12141876.0
#
#      Malaria cases/100,000 pop.  Under-5s (per 100,000)  \
# 95                  4767.864198                  320.48
# 209                 4767.864198                  280.36
# 327                 4540.720539                  264.51
# 444                41789.350000                  257.99
# 517                39920.370090                  229.60
# 586                39920.370090                  206.86
# 658                37881.396050                  196.33
# ...

# %%
df.describe()
# Out:
#               Year     GDP/capita    Population  Malaria cases/100,000 pop.  \
# count   744.000000     744.000000  7.440000e+02                  744.000000
# mean   2009.063172   15610.346529  5.923534e+07                 5531.429072
# std       2.247784   18510.014775  1.875345e+08                11258.159652
# min    2006.000000     738.092490  2.710620e+05                    0.000000
# 25%    2007.000000    2881.321423  4.765863e+06                    0.000000
# 50%    2009.000000    9181.520852  1.250545e+07                   38.025051
# 75%    2011.000000   19502.465020  3.939160e+07                 2034.978756
# max    2013.000000  119723.100700  1.359368e+09                47842.678290
#
#        Under-5s (per 100,000)  All ages (per 100,000)  \
# count              744.000000              744.000000
# mean                88.510551               20.328105
# std                223.030283               48.946384
# min                  0.000000                0.000000
# ...

# %%
df = df.dropna()

# %%
df.count()
# Out:
# Year                              744
# Country                           744
# Country Code                      744
# GDP/capita                        744
# Population                        744
# Malaria cases/100,000 pop.        744
# Under-5s (per 100,000)            744
# All ages (per 100,000)            744
# 70+ years old (per 100,000)       744
# 50-69 years old (per 100,000)     744
# 15-49 years old (per 100,000)     744
# 5-14 years old (per 100,000)      744
# Age-standardized (per 100,000)    744
# Capital                           744
# Latitude                          744
# Longitude                         744
# Latitude Number                   744
# Longitude Number                  744
# dtype: int64

# %%
int('10')
# Out:
# 10
